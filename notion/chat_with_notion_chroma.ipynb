# %%
# %pip install -q chromadb tqdm langchain llama-cpp-python
# Out:
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade --force-reinstall chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-0.4.21-py3-none-any.whl.metadata (7.3 kB)
# Collecting requests>=2.28 (from chromadb)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic>=1.9 (from chromadb)
#   Downloading pydantic-2.5.3-py3-none-any.whl.metadata (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 2.7 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Using cached chroma_hnswlib-0.7.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.105.0-py3-none-any.whl.metadata (24 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting numpy>=1.22.5 (from chromadb)
#   Using cached numpy-1.26.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.1.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.5.0 (from chromadb)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Using cached pulsar_client-3.3.0-cp311-cp311-macosx_10_15_universal2.whl.metadata (1.0 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.16.3-cp311-cp311-macosx_10_15_x86_64.whl.metadata (4.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.15.0-cp311-cp311-macosx_10_7_x86_64.whl.metadata (6.7 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Collecting tqdm>=4.65.0 (from chromadb)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.1.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.60.0-cp311-cp311-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl.metadata (9.5 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-28.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting PyYAML>=6.0.0 (from chromadb)
#   Using cached PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-4.0.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting anyio<4.0.0,>=3.7.1 (from fastapi>=0.95.2->chromadb)
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.27.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting certifi>=14.05.14 (from kubernetes>=28.1.0->chromadb)
#   Using cached certifi-2023.11.17-py3-none-any.whl.metadata (2.2 kB)
# Collecting six>=1.9.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting python-dateutil>=2.5.3 (from kubernetes>=28.1.0->chromadb)
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Downloading google_auth-2.25.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.7.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting urllib3<2.0,>=1.24.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting packaging (from onnxruntime>=1.14.1->chromadb)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Using cached protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata<7.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting backoff<3.0.0,>=1.10.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.22.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-asgi==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl.metadata (5.9 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.43b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting setuptools>=16.0 (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading setuptools-69.0.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached wrapt-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.7.2-py3-none-any.whl.metadata (9.2 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.9->chromadb)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.6 (from pydantic>=1.9->chromadb)
#   Downloading pydantic_core-2.14.6-cp311-cp311-macosx_10_7_x86_64.whl.metadata (6.5 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.28->chromadb)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests>=2.28->chromadb)
#   Using cached idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting huggingface_hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-0.20.1-py3-none-any.whl.metadata (12 kB)
# Collecting click<9.0.0,>=7.1.1 (from typer>=0.9.0->chromadb)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting h11>=0.8 (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvloop-0.19.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.21.0-cp311-cp311-macosx_10_7_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-12.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting sniffio>=1.1 (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting filelock (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting fsspec>=2023.5.0 (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading fsspec-2023.12.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting zipp>=0.5 (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting mpmath>=0.19 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Using cached chromadb-0.4.21-py3-none-any.whl (508 kB)
# Using cached chroma_hnswlib-0.7.3-cp311-cp311-macosx_10_9_x86_64.whl (221 kB)
# Downloading bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl (528 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.5/528.5 kB 12.7 MB/s eta 0:00:0000:01
# Downloading fastapi-0.105.0-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.1 MB/s eta 0:00:00
# Downloading grpcio-1.60.0-cp311-cp311-macosx_10_10_universal2.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 46.9 MB/s eta 0:00:0000:0100:01
# Using cached kubernetes-28.1.0-py2.py3-none-any.whl (1.6 MB)
# Using cached mmh3-4.0.1-cp311-cp311-macosx_10_9_x86_64.whl (34 kB)
# Using cached numpy-1.26.2-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
# Using cached onnxruntime-1.16.3-cp311-cp311-macosx_10_15_x86_64.whl (7.1 MB)
# Downloading opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 10.5 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.7 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl (28 kB)
# Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 12.3 MB/s eta 0:00:00
# Using cached overrides-7.4.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.1.0-py2.py3-none-any.whl (37 kB)
# Using cached pulsar_client-3.3.0-cp311-cp311-macosx_10_15_universal2.whl (10.9 MB)
# Downloading pydantic-2.5.3-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.9/381.9 kB 35.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.14.6-cp311-cp311-macosx_10_7_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 51.0 MB/s eta 0:00:00
# Using cached PyYAML-6.0.1-cp311-cp311-macosx_10_9_x86_64.whl (187 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Using cached tokenizers-0.15.0-cp311-cp311-macosx_10_7_x86_64.whl (2.6 MB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading uvicorn-0.25.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 6.1 MB/s eta 0:00:00
# Using cached importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Using cached certifi-2023.11.17-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl (121 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 kB 18.0 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 26.0 MB/s eta 0:00:00
# Using cached httptools-0.6.1-cp311-cp311-macosx_10_9_x86_64.whl (75 kB)
# Downloading huggingface_hub-0.20.1-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.1/330.1 kB 35.8 MB/s eta 0:00:00
# Using cached idna-3.6-py3-none-any.whl (61 kB)
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Using cached starlette-0.27.0-py3-none-any.whl (66 kB)
# Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# Using cached uvloop-0.19.0-cp311-cp311-macosx_10_9_x86_64.whl (746 kB)
# Using cached watchfiles-0.21.0-cp311-cp311-macosx_10_7_x86_64.whl (428 kB)
# Downloading websocket_client-1.7.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 6.7 MB/s eta 0:00:00
# Using cached websockets-12.0-cp311-cp311-macosx_10_9_x86_64.whl (121 kB)
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached asgiref-3.7.2-py3-none-any.whl (24 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 18.9 MB/s eta 0:00:00
# Downloading setuptools-69.0.3-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 40.6 MB/s eta 0:00:00
# Using cached wrapt-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl (37 kB)
# Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# Installing collected packages: pypika, mpmath, monotonic, mmh3, flatbuffers, zipp, wrapt, websockets, websocket-client, uvloop, urllib3, typing-extensions, tqdm, tenacity, sympy, sniffio, six, setuptools, PyYAML, python-dotenv, pyasn1, protobuf, packaging, overrides, opentelemetry-util-http, opentelemetry-semantic-conventions, oauthlib, numpy, importlib-resources, idna, humanfriendly, httptools, h11, grpcio, fsspec, filelock, click, charset-normalizer, certifi, cachetools, bcrypt, backoff, asgiref, annotated-types, uvicorn, typer, rsa, requests, python-dateutil, pydantic-core, pyasn1-modules, pulsar-client, opentelemetry-proto, importlib-metadata, googleapis-common-protos, deprecated, coloredlogs, chroma-hnswlib, anyio, watchfiles, starlette, requests-oauthlib, pydantic, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, huggingface_hub, google-auth, tokenizers, opentelemetry-sdk, opentelemetry-instrumentation, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: pypika
#     Found existing installation: PyPika 0.48.9
#     Uninstalling PyPika-0.48.9:
#       Successfully uninstalled PyPika-0.48.9
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: monotonic
#     Found existing installation: monotonic 1.6
#     Uninstalling monotonic-1.6:
#       Successfully uninstalled monotonic-1.6
#   Attempting uninstall: mmh3
#     Found existing installation: mmh3 4.0.1
#     Uninstalling mmh3-4.0.1:
#       Successfully uninstalled mmh3-4.0.1
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.17.0
#     Uninstalling zipp-3.17.0:
#       Successfully uninstalled zipp-3.17.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.15.0
#     Uninstalling wrapt-1.15.0:
#       Successfully uninstalled wrapt-1.15.0
#   Attempting uninstall: websockets
#     Found existing installation: websockets 11.0.3
#     Uninstalling websockets-11.0.3:
#       Successfully uninstalled websockets-11.0.3
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.1
#     Uninstalling websocket-client-1.6.1:
#       Successfully uninstalled websocket-client-1.6.1
#   Attempting uninstall: uvloop
#     Found existing installation: uvloop 0.17.0
#     Uninstalling uvloop-0.17.0:
#       Successfully uninstalled uvloop-0.17.0
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.16
#     Uninstalling urllib3-1.26.16:
#       Successfully uninstalled urllib3-1.26.16
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.8.0
#     Uninstalling typing_extensions-4.8.0:
#       Successfully uninstalled typing_extensions-4.8.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.3
#     Uninstalling tenacity-8.2.3:
#       Successfully uninstalled tenacity-8.2.3
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.3.0
#     Uninstalling sniffio-1.3.0:
#       Successfully uninstalled sniffio-1.3.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.2.2
#     Uninstalling setuptools-68.2.2:
#       Successfully uninstalled setuptools-68.2.2
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.0.0
#     Uninstalling python-dotenv-1.0.0:
#       Successfully uninstalled python-dotenv-1.0.0
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.5.0
#     Uninstalling pyasn1-0.5.0:
#       Successfully uninstalled pyasn1-0.5.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.4
#     Uninstalling protobuf-4.23.4:
#       Successfully uninstalled protobuf-4.23.4
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: overrides
#     Found existing installation: overrides 7.4.0
#     Uninstalling overrides-7.4.0:
#       Successfully uninstalled overrides-7.4.0
#   Attempting uninstall: opentelemetry-util-http
#     Found existing installation: opentelemetry-util-http 0.41b0
#     Uninstalling opentelemetry-util-http-0.41b0:
#       Successfully uninstalled opentelemetry-util-http-0.41b0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.41b0
#     Uninstalling opentelemetry-semantic-conventions-0.41b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.41b0
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.2
#     Uninstalling oauthlib-3.2.2:
#       Successfully uninstalled oauthlib-3.2.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.2
#     Uninstalling numpy-1.26.2:
#       Successfully uninstalled numpy-1.26.2
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.1.0
#     Uninstalling importlib-resources-6.1.0:
#       Successfully uninstalled importlib-resources-6.1.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: humanfriendly
#     Found existing installation: humanfriendly 10.0
#     Uninstalling humanfriendly-10.0:
#       Successfully uninstalled humanfriendly-10.0
#   Attempting uninstall: httptools
#     Found existing installation: httptools 0.6.0
#     Uninstalling httptools-0.6.0:
#       Successfully uninstalled httptools-0.6.0
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.59.0
#     Uninstalling grpcio-1.59.0:
#       Successfully uninstalled grpcio-1.59.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.9.2
#     Uninstalling fsspec-2023.9.2:
#       Successfully uninstalled fsspec-2023.9.2
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.12.2
#     Uninstalling filelock-3.12.2:
#       Successfully uninstalled filelock-3.12.2
#   Attempting uninstall: click
#     Found existing installation: click 8.1.6
#     Uninstalling click-8.1.6:
#       Successfully uninstalled click-8.1.6
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.2.0
#     Uninstalling charset-normalizer-3.2.0:
#       Successfully uninstalled charset-normalizer-3.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.1
#     Uninstalling cachetools-5.3.1:
#       Successfully uninstalled cachetools-5.3.1
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 4.0.1
#     Uninstalling bcrypt-4.0.1:
#       Successfully uninstalled bcrypt-4.0.1
#   Attempting uninstall: backoff
#     Found existing installation: backoff 2.2.1
#     Uninstalling backoff-2.2.1:
#       Successfully uninstalled backoff-2.2.1
#   Attempting uninstall: asgiref
#     Found existing installation: asgiref 3.7.2
#     Uninstalling asgiref-3.7.2:
#       Successfully uninstalled asgiref-3.7.2
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.23.1
#     Uninstalling uvicorn-0.23.1:
#       Successfully uninstalled uvicorn-0.23.1
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.0
#     Uninstalling typer-0.9.0:
#       Successfully uninstalled typer-0.9.0
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1-modules 0.3.0
#     Uninstalling pyasn1-modules-0.3.0:
#       Successfully uninstalled pyasn1-modules-0.3.0
#   Attempting uninstall: pulsar-client
#     Found existing installation: pulsar-client 3.3.0
#     Uninstalling pulsar-client-3.3.0:
#       Successfully uninstalled pulsar-client-3.3.0
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.20.0
#     Uninstalling opentelemetry-proto-1.20.0:
#       Successfully uninstalled opentelemetry-proto-1.20.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.8.0
#     Uninstalling importlib-metadata-6.8.0:
#       Successfully uninstalled importlib-metadata-6.8.0
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.59.1
#     Uninstalling googleapis-common-protos-1.59.1:
#       Successfully uninstalled googleapis-common-protos-1.59.1
#   Attempting uninstall: deprecated
#     Found existing installation: Deprecated 1.2.14
#     Uninstalling Deprecated-1.2.14:
#       Successfully uninstalled Deprecated-1.2.14
#   Attempting uninstall: coloredlogs
#     Found existing installation: coloredlogs 15.0.1
#     Uninstalling coloredlogs-15.0.1:
#       Successfully uninstalled coloredlogs-15.0.1
#   Attempting uninstall: chroma-hnswlib
#     Found existing installation: chroma-hnswlib 0.7.3
#     Uninstalling chroma-hnswlib-0.7.3:
#       Successfully uninstalled chroma-hnswlib-0.7.3
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: watchfiles
#     Found existing installation: watchfiles 0.20.0
#     Uninstalling watchfiles-0.20.0:
#       Successfully uninstalled watchfiles-0.20.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.27.0
#     Uninstalling starlette-0.27.0:
#       Successfully uninstalled starlette-0.27.0
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.1
#     Uninstalling requests-oauthlib-1.3.1:
#       Successfully uninstalled requests-oauthlib-1.3.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
#   Attempting uninstall: posthog
#     Found existing installation: posthog 3.0.2
#     Uninstalling posthog-3.0.2:
#       Successfully uninstalled posthog-3.0.2
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.20.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.20.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.20.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.20.0
#     Uninstalling opentelemetry-api-1.20.0:
#       Successfully uninstalled opentelemetry-api-1.20.0
#   Attempting uninstall: onnxruntime
#     Found existing installation: onnxruntime 1.16.0
#     Uninstalling onnxruntime-1.16.0:
#       Successfully uninstalled onnxruntime-1.16.0
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.17.3
#     Uninstalling huggingface-hub-0.17.3:
#       Successfully uninstalled huggingface-hub-0.17.3
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.22.0
#     Uninstalling google-auth-2.22.0:
#       Successfully uninstalled google-auth-2.22.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.20.0
#     Uninstalling opentelemetry-sdk-1.20.0:
#       Successfully uninstalled opentelemetry-sdk-1.20.0
#   Attempting uninstall: opentelemetry-instrumentation
#     Found existing installation: opentelemetry-instrumentation 0.41b0
#     Uninstalling opentelemetry-instrumentation-0.41b0:
#       Successfully uninstalled opentelemetry-instrumentation-0.41b0
#   Attempting uninstall: kubernetes
#     Found existing installation: kubernetes 28.1.0
#     Uninstalling kubernetes-28.1.0:
#       Successfully uninstalled kubernetes-28.1.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.100.1
#     Uninstalling fastapi-0.100.1:
#       Successfully uninstalled fastapi-0.100.1
#   Attempting uninstall: opentelemetry-instrumentation-asgi
#     Found existing installation: opentelemetry-instrumentation-asgi 0.41b0
#     Uninstalling opentelemetry-instrumentation-asgi-0.41b0:
#       Successfully uninstalled opentelemetry-instrumentation-asgi-0.41b0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-grpc
#     Found existing installation: opentelemetry-exporter-otlp-proto-grpc 1.20.0
#     Uninstalling opentelemetry-exporter-otlp-proto-grpc-1.20.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-grpc-1.20.0
#   Attempting uninstall: opentelemetry-instrumentation-fastapi
#     Found existing installation: opentelemetry-instrumentation-fastapi 0.41b0
#     Uninstalling opentelemetry-instrumentation-fastapi-0.41b0:
#       Successfully uninstalled opentelemetry-instrumentation-fastapi-0.41b0
#   Attempting uninstall: chromadb
#     Found existing installation: chromadb 0.4.21
#     Uninstalling chromadb-0.4.21:
#       Successfully uninstalled chromadb-0.4.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# agbenchmark 0.0.2 requires openai<0.28.0,>=0.27.8, but you have openai 1.3.5 which is incompatible.
# agbenchmark 0.0.2 requires pydantic<2.0.0,>=1.10.9, but you have pydantic 2.5.3 which is incompatible.
# agbenchmark 0.0.2 requires python-dotenv<0.22.0,>=0.21.0, but you have python-dotenv 1.0.0 which is incompatible.
# singer-python 5.13.0 requires backoff==1.8.0, but you have backoff 2.2.1 which is incompatible.
# singer-python 5.13.0 requires jsonschema==2.6.0, but you have jsonschema 4.20.0 which is incompatible.
# confection 0.1.0 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.5.3 which is incompatible.
# agent-protocol 1.0.1 requires fastapi<0.101.0,>=0.100.0, but you have fastapi 0.105.0 which is incompatible.
# agent-protocol 1.0.1 requires pydantic<2.0.0,>=1.10.5, but you have pydantic 2.5.3 which is incompatible.
# openapi-python-client 0.13.4 requires pydantic<2.0.0,>=1.6.1, but you have pydantic 2.5.3 which is incompatible.
# openapi-python-client 0.13.4 requires typer<0.8.0,>=0.6, but you have typer 0.9.0 which is incompatible.
# spacy 3.5.4 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.5.3 which is incompatible.
# thinc 8.1.10 requires pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4, but you have pydantic 2.5.3 which is incompatible.
# Successfully installed PyYAML-6.0.1 annotated-types-0.6.0 anyio-3.7.1 asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 cachetools-5.3.2 certifi-2023.11.17 charset-normalizer-3.3.2 chroma-hnswlib-0.7.3 chromadb-0.4.21 click-8.1.7 coloredlogs-15.0.1 deprecated-1.2.14 fastapi-0.105.0 filelock-3.13.1 flatbuffers-23.5.26 fsspec-2023.12.2 google-auth-2.25.2 googleapis-common-protos-1.62.0 grpcio-1.60.0 h11-0.14.0 httptools-0.6.1 huggingface_hub-0.20.1 humanfriendly-10.0 idna-3.6 importlib-metadata-6.11.0 importlib-resources-6.1.1 kubernetes-28.1.0 mmh3-4.0.1 monotonic-1.6 mpmath-1.3.0 numpy-1.26.2 oauthlib-3.2.2 onnxruntime-1.16.3 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 overrides-7.4.0 packaging-23.2 posthog-3.1.0 protobuf-4.25.1 pulsar-client-3.3.0 pyasn1-0.5.1 pyasn1-modules-0.3.0 pydantic-2.5.3 pydantic-core-2.14.6 pypika-0.48.9 python-dateutil-2.8.2 python-dotenv-1.0.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 setuptools-69.0.3 six-1.16.0 sniffio-1.3.0 starlette-0.27.0 sympy-1.12 tenacity-8.2.3 tokenizers-0.15.0 tqdm-4.66.1 typer-0.9.0 typing-extensions-4.9.0 urllib3-1.26.18 uvicorn-0.25.0 uvloop-0.19.0 watchfiles-0.21.0 websocket-client-1.7.0 websockets-12.0 wrapt-1.16.0 zipp-3.17.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 4
#       1 get_ipython().run_line_magic('pip', 'install --upgrade --force-reinstall chromadb')
#       3 import chromadb
# ----> 4 chroma_client = chromadb.Client()
#
# AttributeError: module 'chromadb' has no attribute 'Client'

# %%
# Decide if you want to use LLaMa or OpenAI for the embedding
embedding_model = "openai" # "openai" "llama"

# Decide if you want to use LLaMa or OpenAI for the chat
chat_model = "llama" # "openai" "llama"

# %%
import os
from dotenv import find_dotenv, load_dotenv
# Load environment variables from .env file
load_dotenv(find_dotenv())

# get our OpenAI API key
openai_api_key = os.getenv("OPENAI_API_KEY")

LLaMa_model_path="../../../llama/llama-2-7b-chat/ggml-model-f16_q4_0.gguf"
NOTION_DIRECTORY_PATH="../notion_data/Support_runbook"

# %%
from langchain.document_loaders import NotionDirectoryLoader

loader = NotionDirectoryLoader(NOTION_DIRECTORY_PATH)
data = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
all_splits = text_splitter.split_documents(data)

# %%
# count number of chunks
num_chunks = 0
for doc in all_splits:
    num_chunks += 1

print(f"Total number of chunks: {num_chunks}")
# Out:
# Total number of chunks: 310

# %%
from langchain.embeddings import LlamaCppEmbeddings
from langchain.embeddings.openai import OpenAIEmbeddings

if embedding_model == "llama":
    embeddings = LlamaCppEmbeddings(model_path=LLaMa_model_path)
elif embedding_model == "openai":
    embeddings = OpenAIEmbeddings()

# %%
from langchain.vectorstores import Chroma

chroma_db = Chroma.from_documents(
    documents=all_splits,
    embedding=embeddings, 
    persist_directory="data", 
    collection_name="notion_support_runbook"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 from langchain.vectorstores import Chroma
# ----> 3 chroma_db = Chroma.from_documents(
#       4     documents=all_splits,
#       5     embedding=embeddings,
#       6     persist_directory="data",
#       7     collection_name="notion_support_runbook"
#       8 )
#
# File /usr/local/lib/python3.11/site-packages/langchain_community/vectorstores/chroma.py:771, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     769 texts = [doc.page_content for doc in documents]
#     770 metadatas = [doc.metadata for doc in documents]
# --> 771 return cls.from_texts(
#     772     texts=texts,
#     773     embedding=embedding,
#     774     metadatas=metadatas,
#     775     ids=ids,
#     776     collection_name=collection_name,
#     777     persist_directory=persist_directory,
#     778     client_settings=client_settings,
#     779     client=client,
#     780     collection_metadata=collection_metadata,
#     781     **kwargs,
#     782 )
#
# File /usr/local/lib/python3.11/site-packages/langchain_community/vectorstores/chroma.py:707, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     674 @classmethod
#     675 def from_texts(
#     676     cls: Type[Chroma],
#    (...)
#     686     **kwargs: Any,
#     687 ) -> Chroma:
#     688     """Create a Chroma vectorstore from a raw documents.
#     689
#     690     If a persist_directory is specified, the collection will be persisted there.
#    (...)
#     705         Chroma: Chroma vectorstore.
#     706     """
# --> 707     chroma_collection = cls(
#     708         collection_name=collection_name,
#     709         embedding_function=embedding,
#     710         persist_directory=persist_directory,
#     711         client_settings=client_settings,
#     712         client=client,
#     713         collection_metadata=collection_metadata,
#     714         **kwargs,
#     715     )
#     716     if ids is None:
#     717         ids = [str(uuid.uuid1()) for _ in texts]
#
# File /usr/local/lib/python3.11/site-packages/langchain_community/vectorstores/chroma.py:109, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, client_settings, collection_metadata, client, relevance_score_fn)
#     106     _client_settings = client_settings
#     107 elif persist_directory:
#     108     # Maintain backwards compatibility with chromadb < 0.4.0
# --> 109     major, minor, _ = chromadb.__version__.split(".")
#     110     if int(major) == 0 and int(minor) < 4:
#     111         _client_settings = chromadb.config.Settings(
#     112             chroma_db_impl="duckdb+parquet",
#     113         )
#
# AttributeError: module 'chromadb' has no attribute '__version__'
